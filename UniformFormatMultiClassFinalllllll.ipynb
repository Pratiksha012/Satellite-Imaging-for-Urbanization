# %%
import numpy as np
import rasterio
import tensorflow as tf
import os
from rasterio.mask import mask
import geopandas as gpd
from tensorflow.keras import layers, models
from tensorflow.keras import mixed_precision

# Set float32 for broader compatibility
mixed_precision.set_global_policy('float32')

# --------------------
# Mapping Dictionary
# --------------------
glclu_to_simplified = {
    0: None, 14: 1, 15: 1, 16: 1, 17: 1, 18: 1, 19: 1, 20: 1, 21: 1,
    104: 4, 107: 4, 108: 4,
    100: 3, 112: 3, 111: 3,
    125: 2, 126: 2, 127: 2, 128: 2, 129: 2, 130: 2, 131: 2, 132: 2,
    200: 5, 201: 5, 202: 5, 204: 5, 205: 5, 207: 5,
    244: 9, 250: 7,
    113: 6, 114: 6,
    140: 8, 141: 8, 142: 8, 143: 8, 144: 8
}

# --------------------
# Utilities
# --------------------
def load_and_remap_tif(path, mapping_dict, downsample=2):
    with rasterio.open(path) as src:
        arr = src.read(1).astype(np.uint16)
        if downsample > 1:
            arr = arr[::downsample, ::downsample]
        remapped = np.vectorize(mapping_dict.get)(arr).astype('float32')
        return np.nan_to_num(remapped, nan=0).astype(np.uint8)

def extract_3d_patches(sequence, patch_size=(32, 32), stride=(16, 16)):
    patches = []
    h, w = sequence[0].shape
    for i in range(0, h - patch_size[0] + 1, stride[0]):
        for j in range(0, w - patch_size[1] + 1, stride[1]):
            cube = [img[i:i+patch_size[0], j:j+patch_size[1]] for img in sequence]
            cube = np.stack(cube, axis=0)
            patches.append(cube)
    return np.expand_dims(np.array(patches), axis=-1)

def reconstruct(patches, shape, patch_size=(32, 32), stride=(16, 16)):
    h, w = shape
    result = np.zeros((h, w))
    count = np.zeros((h, w))
    idx = 0
    for i in range(0, h - patch_size[0] + 1, stride[0]):
        for j in range(0, w - patch_size[1] + 1, stride[1]):
            result[i:i+patch_size[0], j:j+patch_size[1]] += patches[idx]
            count[i:i+patch_size[0], j:j+patch_size[1]] += 1
            idx += 1
    return (result / count).round().astype(np.uint8)

def save_tif(img, ref_path, out_path):
    with rasterio.open(ref_path) as src:
        meta = src.meta.copy()
        meta.update(dtype=rasterio.uint8, count=1)
    with rasterio.open(out_path, 'w', **meta) as dst:
        dst.write(img.astype(np.uint8), 1)

# --------------------
# Load Model
# --------------------
model = tf.keras.models.load_model("LandCoverModel_Optimized")
print("✅ Model Loaded")

# --------------------
# Load Training Data
# --------------------
years = [2000, 2005, 2010, 2015, 2020]
file_paths = [f"Covai_LandCover_{year}.tif" for year in years]
data = [load_and_remap_tif(fp, glclu_to_simplified, downsample=2) for fp in file_paths]

# Class Mapping
all_unique = set()
for img in data:
    all_unique.update(np.unique(img))
unique_classes = sorted(all_unique)
class_map = {v: i for i, v in enumerate(unique_classes)}
inverse_class_map = {i: v for v, i in class_map.items()}

data_indexed = [np.vectorize(class_map.get)(img) for img in data]

# --------------------
# Prediction Function
# --------------------
def predict_next(sequence, shape):
    X = extract_3d_patches(sequence)
    preds = model.predict(X, batch_size=2, verbose=1)
    preds = np.argmax(preds, axis=-1)
    return reconstruct(preds, shape)

# --------------------
# Predict Future Years
# --------------------
shape = data[0].shape
pred_2025 = predict_next(data_indexed[1:], shape)
pred_2030 = predict_next([data_indexed[2], data_indexed[3], data_indexed[4], pred_2025], shape)
pred_2035 = predict_next([data_indexed[3], data_indexed[4], pred_2025, pred_2030], shape)
pred_2040 = predict_next([data_indexed[4], pred_2025, pred_2030, pred_2035], shape)

# Map predictions back to land cover codes
pred_2025_mapped = np.vectorize(inverse_class_map.get)(pred_2025)
pred_2030_mapped = np.vectorize(inverse_class_map.get)(pred_2030)
pred_2035_mapped = np.vectorize(inverse_class_map.get)(pred_2035)
pred_2040_mapped = np.vectorize(inverse_class_map.get)(pred_2040)

# --------------------
# Save All as .tif
# --------------------
ref_tif = file_paths[-1]  # Use 2020 as template
save_tif(pred_2025_mapped, ref_tif, "Simplified_Predicted_Simplified_2025.tif")
save_tif(pred_2030_mapped, ref_tif, "Simplified_Predicted_Simplified_2030.tif")
save_tif(pred_2035_mapped, ref_tif, "Simplified_Predicted_Simplified_2035.tif")
save_tif(pred_2040_mapped, ref_tif, "Simplified_Predicted_Simplified_2040.tif")

print("📁 All predictions saved in same format as actual data.")
# Out:
# /Users/pratiksha/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ✅ Model Loaded
# 6528/6528 [==============================] - 81s 12ms/step
# /var/folders/nk/px32ntw90239_n34ks4_61cc0000gn/T/ipykernel_10938/1000111115.py:58: RuntimeWarning: invalid value encountered in divide
#   return (result / count).round().astype(np.uint8)
# /var/folders/nk/px32ntw90239_n34ks4_61cc0000gn/T/ipykernel_10938/1000111115.py:58: RuntimeWarning: invalid value encountered in cast
#   return (result / count).round().astype(np.uint8)
# 6528/6528 [==============================] - 83s 13ms/step
# 6528/6528 [==============================] - 81s 12ms/step
# 6528/6528 [==============================] - 86s 13ms/step
# 📁 All predictions saved in same format as actual data.

# %%
import geopandas as gpd
import rasterio
from rasterio.mask import mask
import numpy as np
import os
from collections import defaultdict

# --- Load Shapefile ---
import os
shapefile_path = "./CBE_Taluk/CBE_TALUKs.shp"

gdf = gpd.read_file(shapefile_path)
gdf = gdf.to_crs("EPSG:4326")  # Ensure same CRS

# --- Define .tif files in order ---
tif_files = {
    "2000": "Simplified_Covai_LandCover_2000.tif",
    "2005": "Simplified_Covai_LandCover_2005.tif",
    "2010": "Simplified_Covai_LandCover_2010.tif",
    "2015": "Simplified_Covai_LandCover_2015.tif",
    "2020": "Simplified_Covai_LandCover_2020.tif",
    "2025": "Predicted_Simplified_2025.tif",
    "2030": "Predicted_Simplified_2030.tif",
    "2035": "Predicted_Simplified_2035.tif",
    "2040": "Predicted_Simplified_2040.tif",
}

# Optional: mapping class numbers to labels
class_labels = {
    1: "Tree Cover", 2: "Shrubland", 3: "Grassland", 4: "Cropland",
    5: "Built-up", 6: "Barren", 7: "Water", 8: "Snow/Ice", 9: "Wetland"
}

# --- Loop Through Each Year & Taluk ---
for year, tif_path in tif_files.items():
    print(f"\n🟨 Year: {year} | File: {tif_path}")

    try:
        with rasterio.open(tif_path) as src:
            for i, row in gdf.iterrows():
                taluk_name = row['NAME_3'] if 'NAME_3' in row else row['NAME']  # Adjust if different
                geom = [row["geometry"]]

                try:
                    out_image, out_transform = mask(src, geom, crop=True)
                    masked = out_image[0]
                    unique, counts = np.unique(masked[masked > 0], return_counts=True)
                    result = dict(zip(unique, counts))

                    print(f"📌 {taluk_name}:")
                    for cls, count in result.items():
                        label = class_labels.get(cls, f"Class {cls}")
                        print(f"   - {label} (class {cls}): {count} pixels")

                except Exception as e:
                    print(f"❌ Could not mask {taluk_name}: {e}")

    except Exception as e:
        print(f"❌ Failed to open {tif_path}: {e}")
# Out:
# 🟨 Year: 2000 | File: Simplified_Covai_LandCover_2000.tif
# 📌 Avanashi:
#    - Tree Cover (class 1): 21394 pixels
#    - Shrubland (class 2): 109 pixels
#    - Grassland (class 3): 17 pixels
#    - Built-up (class 5): 158 pixels
#    - Water (class 7): 115942 pixels
#    - Wetland (class 9): 342203 pixels
# 📌 Coimbatore:
#    - Tree Cover (class 1): 24023 pixels
#    - Shrubland (class 2): 1394 pixels
#    - Built-up (class 5): 2971 pixels
#    - Water (class 7): 324260 pixels
#    - Snow/Ice (class 8): 11 pixels
#    - Wetland (class 9): 333843 pixels
# 📌 Mettuppalaiyam:
#    - Tree Cover (class 1): 2612 pixels
#    - Shrubland (class 2): 321 pixels
#    - Grassland (class 3): 5 pixels
#    - Cropland (class 4): 2 pixels
#    - Built-up (class 5): 3192 pixels
#    - Water (class 7): 56618 pixels
#    - Snow/Ice (class 8): 41 pixels
#    - Wetland (class 9): 189141 pixels
# 📌 Pollachi:
#    - Tree Cover (class 1): 1208 pixels
#    - Shrubland (class 2): 5498 pixels
#    - Grassland (class 3): 60 pixels
#    - Cropland (class 4): 10 pixels
#    - Built-up (class 5): 21490 pixels
#    - Water (class 7): 139556 pixels
#    - Snow/Ice (class 8): 70 pixels
#    - Wetland (class 9): 283440 pixels
# 📌 Tiruppur:
#    - Tree Cover (class 1): 122447 pixels
#    - Shrubland (class 2): 2420 pixels
#    - Built-up (class 5): 1824 pixels
#    - Water (class 7): 373198 pixels
#    - Snow/Ice (class 8): 3 pixels
#    - Wetland (class 9): 539942 pixels
# 📌 Udumalaippettai:
#    - Tree Cover (class 1): 1757 pixels
#    - Shrubland (class 2): 2220 pixels
#    - Built-up (class 5): 13705 pixels
#    - Water (class 7): 124239 pixels
#    - Snow/Ice (class 8): 17 pixels
#    - Wetland (class 9): 561675 pixels
#
# 🟨 Year: 2005 | File: Simplified_Covai_LandCover_2005.tif
# 📌 Avanashi:
#    - Tree Cover (class 1): 20138 pixels
#    - Shrubland (class 2): 104 pixels
#    - Grassland (class 3): 3 pixels
#    - Cropland (class 4): 1 pixels
#    - Built-up (class 5): 280 pixels
#    - Barren (class 6): 14 pixels
#    - Water (class 7): 137318 pixels
#    - Wetland (class 9): 360150 pixels
# 📌 Coimbatore:
#    - Tree Cover (class 1): 22219 pixels
#    - Shrubland (class 2): 964 pixels
#    - Grassland (class 3): 8 pixels
#    - Cropland (class 4): 28 pixels
#    - Built-up (class 5): 3133 pixels
#    - Barren (class 6): 2 pixels
#    - Water (class 7): 364348 pixels
#    - Snow/Ice (class 8): 11 pixels
#    - Wetland (class 9): 313030 pixels
# 📌 Mettuppalaiyam:
#    - Tree Cover (class 1): 2518 pixels
#    - Shrubland (class 2): 235 pixels
#    - Grassland (class 3): 9 pixels
#    - Built-up (class 5): 4636 pixels
#    - Water (class 7): 62970 pixels
#    - Snow/Ice (class 8): 6 pixels
#    - Wetland (class 9): 200067 pixels
# 📌 Pollachi:
#    - Tree Cover (class 1): 971 pixels
#    - Shrubland (class 2): 4313 pixels
#    - Grassland (class 3): 323 pixels
#    - Cropland (class 4): 46 pixels
#    - Built-up (class 5): 18122 pixels
#    - Barren (class 6): 20 pixels
#    - Water (class 7): 160609 pixels
#    - Snow/Ice (class 8): 221 pixels
#    - Wetland (class 9): 265790 pixels
# 📌 Tiruppur:
#    - Tree Cover (class 1): 115837 pixels
#    - Shrubland (class 2): 2195 pixels
#    - Cropland (class 4): 6 pixels
#    - Built-up (class 5): 1505 pixels
#    - Barren (class 6): 24 pixels
#    - Water (class 7): 429656 pixels
#    - Snow/Ice (class 8): 17 pixels
#    - Wetland (class 9): 535875 pixels
# 📌 Udumalaippettai:
#    - Tree Cover (class 1): 1695 pixels
#    - Shrubland (class 2): 2671 pixels
#    - Grassland (class 3): 6 pixels
#    - Cropland (class 4): 1 pixels
#    - Built-up (class 5): 10525 pixels
#    - Water (class 7): 142196 pixels
#    - Snow/Ice (class 8): 56 pixels
#    - Wetland (class 9): 532359 pixels
#
# 🟨 Year: 2010 | File: Simplified_Covai_LandCover_2010.tif
# 📌 Avanashi:
#    - Tree Cover (class 1): 20030 pixels
#    - Shrubland (class 2): 112 pixels
#    - Grassland (class 3): 1 pixels
#    - Built-up (class 5): 9 pixels
#    - Barren (class 6): 1 pixels
#    - Water (class 7): 147758 pixels
#    - Wetland (class 9): 357251 pixels
# 📌 Coimbatore:
#    - Tree Cover (class 1): 18917 pixels
#    - Shrubland (class 2): 768 pixels
#    - Grassland (class 3): 9 pixels
#    - Cropland (class 4): 10 pixels
#    - Built-up (class 5): 4031 pixels
#    - Water (class 7): 392162 pixels
#    - Snow/Ice (class 8): 1 pixels
#    - Wetland (class 9): 305813 pixels
# 📌 Mettuppalaiyam:
#    - Tree Cover (class 1): 2754 pixels
#    - Shrubland (class 2): 238 pixels
#    - Grassland (class 3): 43 pixels
#    - Cropland (class 4): 88 pixels
#    - Built-up (class 5): 4090 pixels
#    - Water (class 7): 65976 pixels
#    - Snow/Ice (class 8): 6 pixels
#    - Wetland (class 9): 200086 pixels
# 📌 Pollachi:
#    - Tree Cover (class 1): 876 pixels
#    - Shrubland (class 2): 1933 pixels
#    - Grassland (class 3): 117 pixels
#    - Cropland (class 4): 38 pixels
#    - Built-up (class 5): 20866 pixels
#    - Water (class 7): 167445 pixels
#    - Snow/Ice (class 8): 246 pixels
#    - Wetland (class 9): 248149 pixels
# 📌 Tiruppur:
#    - Tree Cover (class 1): 107432 pixels
#    - Shrubland (class 2): 1797 pixels
#    - Grassland (class 3): 13 pixels
#    - Cropland (class 4): 10 pixels
#    - Built-up (class 5): 1755 pixels
#    - Barren (class 6): 1 pixels
#    - Water (class 7): 463075 pixels
#    - Snow/Ice (class 8): 18 pixels
#    - Wetland (class 9): 548173 pixels
# 📌 Udumalaippettai:
#    - Tree Cover (class 1): 1840 pixels
#    - Shrubland (class 2): 1742 pixels
#    - Grassland (class 3): 16 pixels
#    - Cropland (class 4): 3 pixels
#    - Built-up (class 5): 12480 pixels
#    - Water (class 7): 145980 pixels
#    - Snow/Ice (class 8): 54 pixels
#    - Wetland (class 9): 515847 pixels
#
# 🟨 Year: 2015 | File: Simplified_Covai_LandCover_2015.tif
# 📌 Avanashi:
#    - Tree Cover (class 1): 15937 pixels
#    - Shrubland (class 2): 152 pixels
#    - Built-up (class 5): 176 pixels
#    - Water (class 7): 178381 pixels
#    - Wetland (class 9): 360206 pixels
# 📌 Coimbatore:
#    - Tree Cover (class 1): 12496 pixels
#    - Shrubland (class 2): 910 pixels
#    - Grassland (class 3): 1 pixels
#    - Cropland (class 4): 2 pixels
#    - Built-up (class 5): 4357 pixels
#    - Water (class 7): 446311 pixels
#    - Snow/Ice (class 8): 1 pixels
#    - Wetland (class 9): 312697 pixels
# 📌 Mettuppalaiyam:
#    - Tree Cover (class 1): 2250 pixels
#    - Shrubland (class 2): 99 pixels
#    - Cropland (class 4): 1 pixels
#    - Built-up (class 5): 4312 pixels
#    - Water (class 7): 76375 pixels
#    - Snow/Ice (class 8): 2 pixels
#    - Wetland (class 9): 200625 pixels
# 📌 Pollachi:
#    - Tree Cover (class 1): 862 pixels
#    - Shrubland (class 2): 349 pixels
#    - Grassland (class 3): 4 pixels
#    - Cropland (class 4): 2 pixels
#    - Built-up (class 5): 21223 pixels
#    - Water (class 7): 192151 pixels
#    - Snow/Ice (class 8): 117 pixels
#    - Wetland (class 9): 238748 pixels
# 📌 Tiruppur:
#    - Tree Cover (class 1): 80251 pixels
#    - Shrubland (class 2): 1598 pixels
#    - Built-up (class 5): 2426 pixels
#    - Water (class 7): 555753 pixels
#    - Snow/Ice (class 8): 12 pixels
#    - Wetland (class 9): 567387 pixels
# 📌 Udumalaippettai:
#    - Tree Cover (class 1): 1737 pixels
#    - Shrubland (class 2): 1509 pixels
#    - Built-up (class 5): 12921 pixels
#    - Water (class 7): 162956 pixels
#    - Snow/Ice (class 8): 26 pixels
#    - Wetland (class 9): 498621 pixels
#
# 🟨 Year: 2020 | File: Simplified_Covai_LandCover_2020.tif
# 📌 Avanashi:
#    - Tree Cover (class 1): 11768 pixels
#    - Shrubland (class 2): 111 pixels
#    - Built-up (class 5): 84 pixels
#    - Water (class 7): 229721 pixels
#    - Wetland (class 9): 356548 pixels
# 📌 Coimbatore:
#    - Tree Cover (class 1): 8032 pixels
#    - Shrubland (class 2): 631 pixels
#    - Cropland (class 4): 1 pixels
#    - Built-up (class 5): 5511 pixels
#    - Water (class 7): 505852 pixels
#    - Snow/Ice (class 8): 2 pixels
#    - Wetland (class 9): 304419 pixels
# 📌 Mettuppalaiyam:
#    - Tree Cover (class 1): 1751 pixels
#    - Shrubland (class 2): 91 pixels
#    - Grassland (class 3): 3 pixels
#    - Built-up (class 5): 5025 pixels
#    - Water (class 7): 94034 pixels
#    - Snow/Ice (class 8): 10 pixels
#    - Wetland (class 9): 192738 pixels
# 📌 Pollachi:
#    - Tree Cover (class 1): 577 pixels
#    - Shrubland (class 2): 227 pixels
#    - Grassland (class 3): 5 pixels
#    - Built-up (class 5): 21830 pixels
#    - Water (class 7): 246426 pixels
#    - Snow/Ice (class 8): 365 pixels
#    - Wetland (class 9): 236053 pixels
# 📌 Tiruppur:
#    - Tree Cover (class 1): 56081 pixels
#    - Shrubland (class 2): 955 pixels
#    - Built-up (class 5): 2267 pixels
#    - Water (class 7): 677245 pixels
#    - Snow/Ice (class 8): 151 pixels
#    - Wetland (class 9): 559767 pixels
# 📌 Udumalaippettai:
#    - Tree Cover (class 1): 1534 pixels
#    - Shrubland (class 2): 1065 pixels
#    - Built-up (class 5): 11225 pixels
#    - Water (class 7): 212077 pixels
#    - Snow/Ice (class 8): 56 pixels
#    - Wetland (class 9): 461257 pixels
#
# 🟨 Year: 2025 | File: Predicted_Simplified_2025.tif
# 📌 Avanashi:
#    - Tree Cover (class 1): 9078 pixels
#    - Shrubland (class 2): 1361 pixels
#    - Grassland (class 3): 4 pixels
#    - Cropland (class 4): 5612 pixels
#    - Built-up (class 5): 340 pixels
#    - Barren (class 6): 111 pixels
#    - Water (class 7): 225598 pixels
#    - Snow/Ice (class 8): 8200 pixels
#    - Wetland (class 9): 362981 pixels
# 📌 Coimbatore:
#    - Tree Cover (class 1): 5496 pixels
#    - Shrubland (class 2): 1515 pixels
#    - Grassland (class 3): 16 pixels
#    - Cropland (class 4): 7022 pixels
#    - Built-up (class 5): 3960 pixels
#    - Barren (class 6): 508 pixels
#    - Water (class 7): 505914 pixels
#    - Snow/Ice (class 8): 7278 pixels
#    - Wetland (class 9): 308104 pixels
# 📌 Mettuppalaiyam:
#    - Tree Cover (class 1): 1368 pixels
#    - Shrubland (class 2): 618 pixels
#    - Cropland (class 4): 2260 pixels
#    - Built-up (class 5): 2560 pixels
#    - Barren (class 6): 172 pixels
#    - Water (class 7): 93778 pixels
#    - Snow/Ice (class 8): 2882 pixels
#    - Wetland (class 9): 193292 pixels
# 📌 Pollachi:
#    - Tree Cover (class 1): 520 pixels
#    - Shrubland (class 2): 1960 pixels
#    - Grassland (class 3): 32 pixels
#    - Cropland (class 4): 6326 pixels
#    - Built-up (class 5): 20525 pixels
#    - Barren (class 6): 640 pixels
#    - Water (class 7): 244075 pixels
#    - Snow/Ice (class 8): 4641 pixels
#    - Wetland (class 9): 238972 pixels
# 📌 Tiruppur:
#    - Tree Cover (class 1): 43919 pixels
#    - Shrubland (class 2): 3838 pixels
#    - Grassland (class 3): 32 pixels
#    - Cropland (class 4): 16520 pixels
#    - Built-up (class 5): 2404 pixels
#    - Barren (class 6): 755 pixels
#    - Water (class 7): 679464 pixels
#    - Snow/Ice (class 8): 15750 pixels
#    - Wetland (class 9): 568705 pixels
# 📌 Udumalaippettai:
#    - Tree Cover (class 1): 1286 pixels
#    - Shrubland (class 2): 1860 pixels
#    - Grassland (class 3): 8 pixels
#    - Cropland (class 4): 5708 pixels
#    - Built-up (class 5): 11376 pixels
#    - Barren (class 6): 252 pixels
#    - Water (class 7): 204379 pixels
#    - Snow/Ice (class 8): 7115 pixels
#    - Wetland (class 9): 462142 pixels
#
# 🟨 Year: 2030 | File: Predicted_Simplified_2030.tif
# 📌 Avanashi:
#    - Tree Cover (class 1): 8586 pixels
#    - Shrubland (class 2): 616 pixels
#    - Grassland (class 3): 4 pixels
#    - Cropland (class 4): 2741 pixels
#    - Built-up (class 5): 230 pixels
#    - Barren (class 6): 120 pixels
#    - Water (class 7): 234793 pixels
#    - Snow/Ice (class 8): 6034 pixels
#    - Wetland (class 9): 366064 pixels
# 📌 Coimbatore:
#    - Tree Cover (class 1): 5135 pixels
#    - Shrubland (class 2): 752 pixels
#    - Grassland (class 3): 4 pixels
#    - Cropland (class 4): 3226 pixels
#    - Built-up (class 5): 3364 pixels
#    - Barren (class 6): 420 pixels
#    - Water (class 7): 516415 pixels
#    - Snow/Ice (class 8): 5193 pixels
#    - Wetland (class 9): 311056 pixels
# 📌 Mettuppalaiyam:
#    - Tree Cover (class 1): 1272 pixels
#    - Shrubland (class 2): 388 pixels
#    - Grassland (class 3): 2 pixels
#    - Cropland (class 4): 1222 pixels
#    - Built-up (class 5): 2392 pixels
#    - Barren (class 6): 140 pixels
#    - Water (class 7): 96736 pixels
#    - Snow/Ice (class 8): 2100 pixels
#    - Wetland (class 9): 194674 pixels
# 📌 Pollachi:
#    - Tree Cover (class 1): 468 pixels
#    - Shrubland (class 2): 938 pixels
#    - Cropland (class 4): 2991 pixels
#    - Built-up (class 5): 20778 pixels
#    - Barren (class 6): 584 pixels
#    - Water (class 7): 251107 pixels
#    - Snow/Ice (class 8): 3521 pixels
#    - Wetland (class 9): 240394 pixels
# 📌 Tiruppur:
#    - Tree Cover (class 1): 42371 pixels
#    - Shrubland (class 2): 2006 pixels
#    - Grassland (class 3): 20 pixels
#    - Cropland (class 4): 8198 pixels
#    - Built-up (class 5): 1968 pixels
#    - Barren (class 6): 713 pixels
#    - Water (class 7): 704096 pixels
#    - Snow/Ice (class 8): 12775 pixels
#    - Wetland (class 9): 574647 pixels
# 📌 Udumalaippettai:
#    - Tree Cover (class 1): 1120 pixels
#    - Shrubland (class 2): 1013 pixels
#    - Grassland (class 3): 12 pixels
#    - Cropland (class 4): 3153 pixels
#    - Built-up (class 5): 12049 pixels
#    - Barren (class 6): 307 pixels
#    - Water (class 7): 210517 pixels
#    - Snow/Ice (class 8): 4899 pixels
#    - Wetland (class 9): 464930 pixels
#
# 🟨 Year: 2035 | File: Predicted_Simplified_2035.tif
# 📌 Avanashi:
#    - Tree Cover (class 1): 8417 pixels
#    - Shrubland (class 2): 298 pixels
#    - Cropland (class 4): 1166 pixels
#    - Built-up (class 5): 160 pixels
#    - Barren (class 6): 56 pixels
#    - Water (class 7): 238785 pixels
#    - Snow/Ice (class 8): 4354 pixels
#    - Wetland (class 9): 367918 pixels
# 📌 Coimbatore:
#    - Tree Cover (class 1): 5000 pixels
#    - Shrubland (class 2): 358 pixels
#    - Cropland (class 4): 1296 pixels
#    - Built-up (class 5): 2728 pixels
#    - Barren (class 6): 312 pixels
#    - Water (class 7): 521083 pixels
#    - Snow/Ice (class 8): 3715 pixels
#    - Wetland (class 9): 312875 pixels
# 📌 Mettuppalaiyam:
#    - Tree Cover (class 1): 1214 pixels
#    - Shrubland (class 2): 192 pixels
#    - Cropland (class 4): 514 pixels
#    - Built-up (class 5): 2124 pixels
#    - Barren (class 6): 124 pixels
#    - Water (class 7): 98447 pixels
#    - Snow/Ice (class 8): 1697 pixels
#    - Wetland (class 9): 195148 pixels
# 📌 Pollachi:
#    - Tree Cover (class 1): 428 pixels
#    - Shrubland (class 2): 507 pixels
#    - Grassland (class 3): 4 pixels
#    - Cropland (class 4): 1247 pixels
#    - Built-up (class 5): 20111 pixels
#    - Barren (class 6): 559 pixels
#    - Water (class 7): 254377 pixels
#    - Snow/Ice (class 8): 2528 pixels
#    - Wetland (class 9): 241444 pixels
# 📌 Tiruppur:
#    - Tree Cover (class 1): 41827 pixels
#    - Shrubland (class 2): 984 pixels
#    - Grassland (class 3): 12 pixels
#    - Cropland (class 4): 3669 pixels
#    - Built-up (class 5): 1340 pixels
#    - Barren (class 6): 512 pixels
#    - Water (class 7): 716156 pixels
#    - Snow/Ice (class 8): 8996 pixels
#    - Wetland (class 9): 578721 pixels
# 📌 Udumalaippettai:
#    - Tree Cover (class 1): 1084 pixels
#    - Shrubland (class 2): 504 pixels
#    - Grassland (class 3): 16 pixels
#    - Cropland (class 4): 1164 pixels
#    - Built-up (class 5): 11805 pixels
#    - Barren (class 6): 285 pixels
#    - Water (class 7): 214434 pixels
#    - Snow/Ice (class 8): 3712 pixels
#    - Wetland (class 9): 466198 pixels
#
# 🟨 Year: 2040 | File: Predicted_Simplified_2040.tif
# 📌 Avanashi:
#    - Tree Cover (class 1): 8355 pixels
#    - Shrubland (class 2): 142 pixels
#    - Grassland (class 3): 4 pixels
#    - Cropland (class 4): 508 pixels
#    - Built-up (class 5): 56 pixels
#    - Barren (class 6): 39 pixels
#    - Water (class 7): 240689 pixels
#    - Snow/Ice (class 8): 3329 pixels
#    - Wetland (class 9): 368730 pixels
# 📌 Coimbatore:
#    - Tree Cover (class 1): 4914 pixels
#    - Shrubland (class 2): 140 pixels
#    - Cropland (class 4): 592 pixels
#    - Built-up (class 5): 2148 pixels
#    - Barren (class 6): 256 pixels
#    - Water (class 7): 523305 pixels
#    - Snow/Ice (class 8): 2780 pixels
#    - Wetland (class 9): 313835 pixels
# 📌 Mettuppalaiyam:
#    - Tree Cover (class 1): 1202 pixels
#    - Shrubland (class 2): 112 pixels
#    - Cropland (class 4): 228 pixels
#    - Built-up (class 5): 1728 pixels
#    - Barren (class 6): 160 pixels
#    - Water (class 7): 99347 pixels
#    - Snow/Ice (class 8): 1232 pixels
#    - Wetland (class 9): 195535 pixels
# 📌 Pollachi:
#    - Tree Cover (class 1): 420 pixels
#    - Shrubland (class 2): 328 pixels
#    - Grassland (class 3): 8 pixels
#    - Cropland (class 4): 658 pixels
#    - Built-up (class 5): 19094 pixels
#    - Barren (class 6): 712 pixels
#    - Water (class 7): 256120 pixels
#    - Snow/Ice (class 8): 1822 pixels
#    - Wetland (class 9): 242166 pixels
# 📌 Tiruppur:
#    - Tree Cover (class 1): 41311 pixels
#    - Shrubland (class 2): 570 pixels
#    - Grassland (class 3): 8 pixels
#    - Cropland (class 4): 1670 pixels
#    - Built-up (class 5): 884 pixels
#    - Barren (class 6): 317 pixels
#    - Water (class 7): 721974 pixels
#    - Snow/Ice (class 8): 6548 pixels
#    - Wetland (class 9): 580682 pixels
# 📌 Udumalaippettai:
#    - Tree Cover (class 1): 1044 pixels
#    - Shrubland (class 2): 264 pixels
#    - Grassland (class 3): 16 pixels
#    - Cropland (class 4): 490 pixels
#    - Built-up (class 5): 11434 pixels
#    - Barren (class 6): 276 pixels
#    - Water (class 7): 216094 pixels
#    - Snow/Ice (class 8): 2713 pixels
#    - Wetland (class 9): 467165 pixels

# %%
import rasterio

with rasterio.open("Simplified_Covai_LandCover_2000.tif") as src:
    print("CRS:", src.crs)
    print("Transform:", src.transform)
    print("Pixel size (width x height):", src.res)
    print("Bounds:", src.bounds)
# Out:
# CRS: EPSG:4326
# Transform: | 0.00, 0.00, 76.65|
# | 0.00,-0.00, 11.40|
# | 0.00, 0.00, 1.00|
# Pixel size (width x height): (0.00026949458523585647, 0.00026949458523585647)
# Bounds: BoundingBox(left=76.6472393684927, bottom=10.208448272299776, right=77.4904879256957, top=11.396919393189904)

# %%
from rasterio.io import MemoryFile

# Inside the loop where you already calculated `temp_raster`, `transform`, etc.
with MemoryFile() as memfile:
    with memfile.open(
        driver="GTiff",
        height=height,
        width=width,
        count=1,
        dtype=temp_raster.dtype,
        crs=dst_crs,
        transform=transform,
    ) as dataset:
        dataset.write(temp_raster[0], 1)

        for i, row in gdf_utm.iterrows():
            taluk_name = row.get("NAME_3") or row.get("NAME") or f"Taluk_{i}"
            geom = [row.geometry]

            try:
                out_image, _ = mask(dataset, geom, crop=True, all_touched=True)
                masked = out_image[0]
                unique, counts = np.unique(masked[masked > 0], return_counts=True)

                for cls, count in zip(unique, counts):
                    land_type = class_labels.get(cls, f"Class_{cls}")
                    area_ha = count * pixel_area_ha
                    results[land_type][taluk_name][year] = area_ha

            except Exception as e:
                print(f"⚠️ No overlap or mask fail for {taluk_name}: {e}")

# %%
import geopandas as gpd
import rasterio
from rasterio.mask import mask
from rasterio.warp import calculate_default_transform, reproject, Resampling
from rasterio.io import MemoryFile
import numpy as np
from collections import defaultdict

# --- Load Taluk Shapefile and Convert to UTM ---
shapefile_path = "./CBE_Taluk/CBE_TALUKs.shp"
gdf = gpd.read_file(shapefile_path)
gdf = gdf.to_crs("EPSG:4326")  # Match initial .tif CRS

# --- Convert Shapefile to UTM for accurate area computation ---
utm_crs = "EPSG:32643"  # UTM zone 43N (suitable for Tamil Nadu region)
gdf_utm = gdf.to_crs(utm_crs)

# --- Define Land Cover .tif Files ---
tif_files = {
    "2000": "Simplified_Covai_LandCover_2000.tif",
    "2005": "Simplified_Covai_LandCover_2005.tif",
    "2010": "Simplified_Covai_LandCover_2010.tif",
    "2015": "Simplified_Covai_LandCover_2015.tif",
    "2020": "Simplified_Covai_LandCover_2020.tif",
    "2025": "Predicted_Simplified_2025.tif",
    "2030": "Predicted_Simplified_2030.tif",
    "2035": "Predicted_Simplified_2035.tif",
    "2040": "Predicted_Simplified_2040.tif",
}

# --- Class Labels ---
class_labels = {
    1: "Tree Cover", 2: "Shrubland", 3: "Grassland", 4: "Cropland",
    5: "Built-up", 6: "Barren", 7: "Water", 8: "Snow/Ice", 9: "Wetland"
}

# --- Results Dictionary ---
results = defaultdict(lambda: defaultdict(dict))

# --- Loop Through Each Year ---
for year, tif_path in tif_files.items():
    print(f"\n🟨 Processing Year: {year} | File: {tif_path}")

    try:
        with rasterio.open(tif_path) as src:
            src_crs = src.crs
            transform, width, height = calculate_default_transform(
                src.crs, utm_crs, src.width, src.height, *src.bounds
            )

            # Reproject the raster to UTM
            temp_raster = np.empty((1, height, width), dtype=src.dtypes[0])
            reproject(
                source=rasterio.band(src, 1),
                destination=temp_raster,
                src_transform=src.transform,
                src_crs=src.crs,
                dst_transform=transform,
                dst_crs=utm_crs,
                resampling=Resampling.nearest
            )

            # Calculate pixel area in hectares (1 ha = 10,000 m²)
            pixel_width = transform[0]
            pixel_height = -transform[4]
            pixel_area_ha = pixel_width * pixel_height / 10000
            print(f"📏 Pixel area: {pixel_width * pixel_height:.2f} m² ≈ {pixel_area_ha:.4f} ha")

            # Write reprojected raster to memory and apply mask
            with MemoryFile() as memfile:
                with memfile.open(
                    driver="GTiff",
                    height=height,
                    width=width,
                    count=1,
                    dtype=temp_raster.dtype,
                    crs=utm_crs,
                    transform=transform,
                ) as dataset:
                    dataset.write(temp_raster[0], 1)

                    for i, row in gdf_utm.iterrows():
                        taluk_name = row.get("NAME_3") or row.get("NAME") or f"Taluk_{i}"
                        geom = [row.geometry]

                        try:
                            out_image, _ = mask(dataset, geom, crop=True, all_touched=True)
                            masked = out_image[0]
                            unique, counts = np.unique(masked[masked > 0], return_counts=True)

                            if len(unique) == 0:
                                print(f"⚠️ No data for {taluk_name}")
                                continue

                            print(f"📌 {taluk_name} ({year}):")
                            for cls, count in zip(unique, counts):
                                land_type = class_labels.get(cls, f"Class_{cls}")
                                area_ha = count * pixel_area_ha
                                results[land_type][taluk_name][year] = area_ha
                                print(f"   - {land_type} ({cls}): {area_ha:.2f} ha")

                        except Exception as e:
                            print(f"⚠️ No overlap or mask fail for {taluk_name}: {e}")
    except Exception as e:
        print(f"❌ Failed to process {tif_path}: {e}")
# Out:
# 🟨 Processing Year: 2000 | File: Simplified_Covai_LandCover_2000.tif
# 📏 Pixel area: 882.33 m² ≈ 0.0882 ha
# 📌 Avanashi (2000):
#    - Tree Cover (1): 1899.83 ha
#    - Shrubland (2): 9.97 ha
#    - Grassland (3): 1.50 ha
#    - Built-up (5): 13.85 ha
#    - Water (7): 10219.99 ha
#    - Wetland (9): 30196.94 ha
# 📌 Coimbatore (2000):
#    - Tree Cover (1): 2121.64 ha
#    - Shrubland (2): 122.64 ha
#    - Built-up (5): 260.90 ha
#    - Water (7): 28495.81 ha
#    - Snow/Ice (8): 0.97 ha
#    - Wetland (9): 29403.90 ha
# 📌 Mettuppalaiyam (2000):
tif
# 📏 Pixel area: 882.33 m² ≈ 0.0882 ha
# 📌 Avanashi (2040):
#    - Tree Cover (1): 738.77 ha
#    - Shrubland (2): 12.44 ha
#    - Grassland (3): 0.35 ha
#    - Cropland (4): 45.09 ha
#    - Built-up (5): 4.94 ha
#    - Barren (6): 3.53 ha
#    - Water (7): 21232.41 ha
#    - Snow/Ice (8): 293.11 ha
#    - Wetland (9): 32507.14 ha
# 📌 Coimbatore (2040):
#    - Tree Cover (1): 433.84 ha
#    - Shrubland (2): 12.35 ha
#    - Cropland (4): 51.70 ha
#    - Built-up (5): 188.47 ha
#    - Barren (6): 22.68 ha
#    - Water (7): 46014.06 ha
#    - Snow/Ice (8): 244.32 ha
#    - Wetland (9): 27638.46 ha
# 📌 Mettuppalaiyam (2040):
#    - Tree Cover (1): 105.97 ha
#    - Shrubland (2): 9.88 ha
#    - Cropland (4): 20.29 ha
#    - Built-up (5): 151.67 ha
#    - Barren (6): 14.03 ha
#    - Water (7): 8740.24 ha
#    - Snow/Ice (8): 108.97 ha
#    - Wetland (9): 17232.20 ha
# 📌 Pollachi (2040):
#    - Tree Cover (1): 36.53 ha
#    - Shrubland (2): 29.38 ha
#    - Grassland (3): 0.79 ha
#    - Cropland (4): 57.35 ha
#    - Built-up (5): 1682.33 ha
#    - Barren (6): 62.12 ha
#    - Water (7): 22549.90 ha
#    - Snow/Ice (8): 160.76 ha
#    - Wetland (9): 21356.90 ha
# 📌 Tiruppur (2040):
#    - Tree Cover (1): 3640.48 ha
#    - Shrubland (2): 50.29 ha
#    - Grassland (3): 0.71 ha
#    - Cropland (4): 147.17 ha
#    - Built-up (5): 77.82 ha
#    - Barren (6): 28.50 ha
#    - Water (7): 63570.43 ha
#    - Snow/Ice (8): 576.87 ha
#    - Wetland (9): 51189.35 ha
# 📌 Udumalaippettai (2040):
#    - Tree Cover (1): 91.32 ha
#    - Shrubland (2): 23.82 ha
#    - Grassland (3): 1.59 ha
#    - Cropland (4): 43.50 ha
#    - Built-up (5): 1010.00 ha
#    - Barren (6): 24.62 ha
#    - Water (7): 19030.38 ha
#    - Snow/Ice (8): 239.64 ha
#    - Wetland (9): 41164.62 ha

# %%
import geopandas as gpd
import rasterio
from rasterio.mask import mask
from rasterio.warp import calculate_default_transform, reproject, Resampling
from rasterio.io import MemoryFile
import numpy as np
import pandas as pd
from collections import defaultdict
import re

# --- Load Taluk Shapefile and Convert to UTM ---
shapefile_path = "./CBE_Taluk/CBE_TALUKs.shp"
gdf = gpd.read_file(shapefile_path)
gdf = gdf.to_crs("EPSG:4326")

utm_crs = "EPSG:32643"  # UTM for Tamil Nadu
gdf_utm = gdf.to_crs(utm_crs)

# --- Define Land Cover .tif Files ---
tif_files = {
    "2000": "Simplified_Covai_LandCover_2000.tif",
    "2005": "Simplified_Covai_LandCover_2005.tif",
    "2010": "Simplified_Covai_LandCover_2010.tif",
    "2015": "Simplified_Covai_LandCover_2015.tif",
    "2020": "Simplified_Covai_LandCover_2020.tif",
    "2025": "Predicted_Simplified_2025.tif",
    "2030": "Predicted_Simplified_2030.tif",
    "2035": "Predicted_Simplified_2035.tif",
    "2040": "Predicted_Simplified_2040.tif",
}

# --- Land Cover Class Labels ---
class_labels = {
    1: "Tree Cover", 2: "Shrubland", 3: "Grassland", 4: "Cropland",
    5: "Built-up", 6: "Barren", 7: "Water", 8: "Snow/Ice", 9: "Wetland"
}

# --- Output Container ---
results = defaultdict(lambda: defaultdict(dict))  # {class -> {taluk -> {year -> hectares}}}

# --- Loop Over All Years ---
for year, tif_path in tif_files.items():
    print(f"\n🟨 Processing Year: {year} | File: {tif_path}")
    try:
        with rasterio.open(tif_path) as src:
            # Reproject raster to UTM for accurate area calc
            transform, width, height = calculate_default_transform(
                src.crs, utm_crs, src.width, src.height, *src.bounds
            )

            temp_raster = np.empty((1, height, width), dtype=src.dtypes[0])
            reproject(
                source=rasterio.band(src, 1),
                destination=temp_raster,
                src_transform=src.transform,
                src_crs=src.crs,
                dst_transform=transform,
                dst_crs=utm_crs,
                resampling=Resampling.nearest
            )

            pixel_width = transform[0]
            pixel_height = -transform[4]
            pixel_area_ha = pixel_width * pixel_height / 10000
            print(f"📏 Pixel area: {pixel_width * pixel_height:.2f} m² ≈ {pixel_area_ha:.4f} ha")

            # Use memory file to apply mask on reprojected raster
            with MemoryFile() as memfile:
                with memfile.open(
                    driver="GTiff",
                    height=height,
                    width=width,
                    count=1,
                    dtype=temp_raster.dtype,
                    crs=utm_crs,
                    transform=transform,
                ) as dataset:
                    dataset.write(temp_raster[0], 1)

                    for i, row in gdf_utm.iterrows():
                        taluk_name = row.get("NAME_3") or row.get("NAME") or f"Taluk_{i}"
                        geom = [row.geometry]

                        try:
                            out_image, _ = mask(dataset, geom, crop=True, all_touched=True)
                            masked = out_image[0]
                            unique, counts = np.unique(masked[masked > 0], return_counts=True)

                            for cls, count in zip(unique, counts):
                                land_type = class_labels.get(cls, f"Class_{cls}")
                                area_ha = count * pixel_area_ha
                                results[land_type][taluk_name][year] = area_ha
                        except Exception as e:
                            print(f"⚠️ No overlap or mask fail for {taluk_name}: {e}")
    except Exception as e:
        print(f"❌ Failed to open {tif_path}: {e}")

# --- Save Results to Excel ---
def sanitize_sheet_name(name):
    return re.sub(r'[\\/*?:\[\]]', "_", name)[:31]

output_file = "LandCover_Talukwise_Hectares.xlsx"
with pd.ExcelWriter(output_file) as writer:
    for land_type, taluk_data in results.items():
        df = pd.DataFrame(taluk_data).T  # rows = taluks, columns = years
        df.index.name = "Taluk"
        df = df.reindex(sorted(df.columns), axis=1)  # sort years
        df.fillna(0, inplace=True)
        df = df.astype(float).round(2)

        if df.empty:
            continue

        safe_name = sanitize_sheet_name(land_type)
        df.to_excel(writer, sheet_name=safe_name)

print(f"\n✅ Saved to '{output_file}' in hectares ✅")
# Out:
# 🟨 Processing Year: 2000 | File: Simplified_Covai_LandCover_2000.tif
# 📏 Pixel area: 882.33 m² ≈ 0.0882 ha
#
# 🟨 Processing Year: 2005 | File: Simplified_Covai_LandCover_2005.tif
# 📏 Pixel area: 882.33 m² ≈ 0.0882 ha
#
# 🟨 Processing Year: 2010 | File: Simplified_Covai_LandCover_2010.tif
# 📏 Pixel area: 882.33 m² ≈ 0.0882 ha
#
# 🟨 Processing Year: 2015 | File: Simplified_Covai_LandCover_2015.tif
# 📏 Pixel area: 882.33 m² ≈ 0.0882 ha
#
# 🟨 Processing Year: 2020 | File: Simplified_Covai_LandCover_2020.tif
# 📏 Pixel area: 882.33 m² ≈ 0.0882 ha
#
# 🟨 Processing Year: 2025 | File: Predicted_Simplified_2025.tif
# 📏 Pixel area: 882.33 m² ≈ 0.0882 ha
#
# 🟨 Processing Year: 2030 | File: Predicted_Simplified_2030.tif
# 📏 Pixel area: 882.33 m² ≈ 0.0882 ha
#
# 🟨 Processing Year: 2035 | File: Predicted_Simplified_2035.tif
# 📏 Pixel area: 882.33 m² ≈ 0.0882 ha
#
# 🟨 Processing Year: 2040 | File: Predicted_Simplified_2040.tif
# 📏 Pixel area: 882.33 m² ≈ 0.0882 ha
#
# ✅ Saved to 'LandCover_Talukwise_Hectares.xlsx' in hectares ✅
